# %% [markdown]
# ### Ceci est un titre

# %%
#ceci est un commentaire dans du code
#nous allons travailler en collaboration sur ce fichier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ce que nous devrons faire:
#   + Importer les données Occitanie journalière/mensuelle/annuelle (que choisir?)
#   + Se renseigner sur la manière de procéder grâce à l'ipynb ANOVA

# %% [markdown]
# ## Importation et traitement des données mensuelles:

# %%
from download import download

url = "https://opendata.arcgis.com/datasets/3acfa2aa5c0346a18ba7749c6885e503_0.csv" # lien du site pour les data
path_target = "datasets/Mesure_mensuelle_Region_Occitanie_Polluants_Principaux.csv" # lieu de l'import des données
download(url, path_target, replace=True)
# Out:
# Downloading data from https://opendata.arcgis.com/datasets/3acfa2aa5c0346a18ba7749c6885e503_0.csv (1 byte)
# file_sizes: 311kB [00:00, 563kB/s]
# Successfully downloaded file to datasets/Mesure_mensuelle_Region_Occitanie_Polluants_Principaux.csv
# 'datasets/Mesure_mensuelle_Region_Occitanie_Polluants_Principaux.csv'

# %%
data_occ = pd.read_csv(path_target)
# Dans data_occ sont stockées les données
# Out:
#            X       Y       nom_dept   nom_com  insee_com  \
# 0     1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 1     1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 2     1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 3     1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 4     1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# ...      ...     ...            ...       ...        ...
# 1616  1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 1617  1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 1618  1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 1619  1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
# 1620  1.4496  43.574  HAUTE-GARONNE  TOULOUSE      31555
#
#                        nom_station code_station typologie influence nom_poll  \
# 0     Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 1     Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 2     Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 3     Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 4     Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# ...                            ...          ...       ...       ...      ...
# 1616  Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 1617  Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 1618  Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 1619  Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
# 1620  Toulouse-Périphérique Trafic      FR50048   Urbaine    Trafic       NO
#
#       id_poll_ue  valeur   unite   metrique                date_debut  \
# 0             38    59.7  ug.m-3  mensuelle  2018-08-01T01:00:00.000Z
# 1             38    78.8  ug.m-3  mensuelle  2018-09-01T01:00:00.000Z
# 2             38    85.3  ug.m-3  mensuelle  2018-10-01T01:00:00.000Z
# 3             38   107.7  ug.m-3  mensuelle  2018-11-01T01:00:00.000Z
# 4             38   123.5  ug.m-3  mensuelle  2018-12-01T01:00:00.000Z
# ...          ...     ...     ...        ...                       ...
# 1616          38    81.8  ug.m-3  mensuelle  2018-03-01T01:00:00.000Z
# 1617          38    66.7  ug.m-3  mensuelle  2018-04-01T01:00:00.000Z
# 1618          38    59.7  ug.m-3  mensuelle  2018-05-01T01:00:00.000Z
# 1619          38    69.0  ug.m-3  mensuelle  2018-06-01T01:00:00.000Z
# 1620          38    61.9  ug.m-3  mensuelle  2018-07-01T01:00:00.000Z
#
#                       date_fin statut_valid   x_l93    y_l93  ObjectId
# 0     2018-09-01T00:00:00.000Z            t  573544  6276247      1001
# 1     2018-10-01T00:00:00.000Z            t  573544  6276247      1002
# 2     2018-11-01T00:00:00.000Z            t  573544  6276247      1003
# 3     2018-12-01T00:00:00.000Z            t  573544  6276247      1004
# 4     2019-01-01T00:00:00.000Z            t  573544  6276247      1005
# ...                        ...          ...     ...      ...       ...
# 1616  2018-04-01T00:00:00.000Z            t  573544  6276247       996
# 1617  2018-05-01T00:00:00.000Z            t  573544  6276247       997
# 1618  2018-06-01T00:00:00.000Z            t  573544  6276247       998
# 1619  2018-07-01T00:00:00.000Z            t  573544  6276247       999
# 1620  2018-08-01T00:00:00.000Z            t  573544  6276247      1000
#
# [1621 rows x 20 columns]
