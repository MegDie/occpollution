# %% [markdown]
# ### Ceci est un titre: Occitanie polution

# %%
# ceci est un commentaire dans du code
# nous allons travailler en collaboration sur ce fichier
# svp essayer de rédiger directement en pep8
# rediger en anglais à terme également

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact  # widget manipulation

pd.options.display.max_rows = 8

# %% [markdown]
# *Ceci est une cellule Markdown, elle contient du (joli) texte et non du code*
#
# ## Ce que nous devrons faire:
# ***Au fur et à mesure je rentrerai les tâches à faire et l'aide dont j'ai besoin ici***
#
#   + Se renseigner sur la manière de procéder grâce aux items suivants :
#     + https://nordicesmhub.github.io/deep_python/14-publish/index.html
#     + http://josephsalmon.eu/enseignement/Montpellier/HMMA307/ANOVA.ipynb (à télécharger et étudier en profondeur, c'est la base de la base !!)
#     + Revoir les TPs: Pandas, package_tutorial, etc.
#
# **CETTE ETAPE EST ESSENTIELLE POUR SAVOIR COMMENT PROCEDER PAR LA SUITE**
#
#   + Importer les données Occitanie journalière/mensuelle/annuelle (que choisir?) : **OK (Mégane)**
#   + Trouver une map de l'occitanie, un peu comme la map dans le tp fait en cours mais juste pour l'occitanie et pas pour la France:
#   + Choix de 3 villes avec le bon nombre de données pour le widget version simple: **OK (Mégane)**
#   + Faire une description des variables et des données de notre jeu de données importé (cf TP Pandas):
#      +  description des variables, divers histogrammes:
#      +  etc.:
#   + Trouver une problématique pour notre projet ! :
#
# **A terme, notre projet devra fournir:**
#   + Une vidéo du niveau d'ozone en fonction du temps dans les villes d'occitanie, via certainement une map qui évolue en fonction du temps (contrainte: un cercle plus ou moins gros devra indiquer le niveau d'ozone) *DIFFICULTE +++*
#   + Un "widget" qui compare les niveaux de pollution de 3 villes grâce à des boxplot/violons *DIFFICULTE +*
#   + *DIFFICULTE ++* : faire varier le widget en fonction du temps
#   + Une comparaison Paris VS Montpellier *DIFFICULTE ?*

# %% [markdown]
# ## Importation et traitement des données mensuelles:

# %%
from download import download
# on a choisi les données journalières (pour l'instant...)

url = "https://opendata.arcgis.com/datasets/2ab16a5fb61f42c1a689fd9cc466383f_0.csv"
path_target = "datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv"
download(url, path_target, replace=True)
# Out:
# Downloading data from https://opendata.arcgis.com/datasets/2ab16a5fb61f42c1a689fd9cc466383f_0.csv (1 byte)
# Successfully downloaded file to datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv
# file_sizes: 10.9MB [00:11, 1.12MB/s]
# 'datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv'

# %%
occ = pd.read_csv(path_target)
# Dans occ sont stockées les données de toute l'occitanie

occ # le plus simple pour visualiser la tête du tableau
# Out:
#               X        Y         nom_dept   nom_com  insee_com  \
# 0      1.438610  43.6236    HAUTE-GARONNE  TOULOUSE      31555
# 1      1.467650  43.6431    HAUTE-GARONNE  TOULOUSE      31555
# 2      1.415180  43.6103    HAUTE-GARONNE  TOULOUSE      31555
# 3      1.415180  43.6103    HAUTE-GARONNE  TOULOUSE      31555
# 4      1.443890  43.5872    HAUTE-GARONNE  TOULOUSE      31555
# ...         ...      ...              ...       ...        ...
# 55720 -0.038889  43.0969  HAUTES-PYRENEES   LOURDES      65286
# 55721  1.443890  43.5872    HAUTE-GARONNE  TOULOUSE      31555
# 55722  2.146110  43.9281             TARN      ALBI      81004
# 55723  1.443890  43.5872    HAUTE-GARONNE  TOULOUSE      31555
# 55724  2.230000  43.6106             TARN   CASTRES      81065
#
#                          nom_station code_station typologie influence  \
# 0            Toulouse-Mazades Urbain      FR50021   Urbaine      Fond
# 1         Toulouse - Rte Albi Trafic      FR50054   Urbaine    Trafic
# 2      Toulouse Port de l Embouchure      FR50821   Urbaine    Trafic
# 3      Toulouse Port de l Embouchure      FR50821   Urbaine    Trafic
# 4          Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond
# ...                              ...          ...       ...       ...
# 55720          Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond
# 55721      Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond
# 55722                    Albi Urbain      FR50026   Urbaine      Fond
# 55723      Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond
# 55724          Castres-Travet Urbain      FR50053   Urbaine      Fond
#
#          nom_poll  id_poll_ue  valeur   unite     metrique  \
# 0            PM10           5    19.2  ug.m-3  journaliere
# 1            PM10           5    32.7  ug.m-3  journaliere
# 2      NOX as NO2           9    27.2  ug.m-3  journaliere
# 3            PM10           5    20.1  ug.m-3  journaliere
# 4            PM10           5    20.5  ug.m-3  journaliere
# ...           ...         ...     ...     ...          ...
# 55720          O3           7    67.3  ug.m-3  journaliere
# 55721  NOX as NO2           9     8.1  ug.m-3  journaliere
# 55722          O3           7    73.1  ug.m-3  journaliere
# 55723       PM2.5        6001     2.6  ug.m-3  journaliere
# 55724          O3           7    65.7  ug.m-3  journaliere
#
#                      date_debut                  date_fin statut_valid  \
# 0      2020-01-15T01:00:00.000Z  2020-01-16T00:00:00.000Z            t
# 1      2020-01-15T01:00:00.000Z  2020-01-16T00:00:00.000Z            t
# 2      2020-01-15T01:00:00.000Z  2020-01-16T00:00:00.000Z            t
# 3      2020-01-15T01:00:00.000Z  2020-01-16T00:00:00.000Z            t
# 4      2020-01-15T01:00:00.000Z  2020-01-16T00:00:00.000Z            t
# ...                         ...                       ...          ...
# 55720  2019-05-05T01:00:00.000Z  2019-05-06T00:00:00.000Z            t
# 55721  2019-05-05T01:00:00.000Z  2019-05-06T00:00:00.000Z            t
# 55722  2019-05-05T01:00:00.000Z  2019-05-06T00:00:00.000Z            t
# 55723  2019-05-05T01:00:00.000Z  2019-05-06T00:00:00.000Z            t
# 55724  2019-05-05T01:00:00.000Z  2019-05-06T00:00:00.000Z            t
#
#         x_l93    y_l93  ObjectId
# 0      573948  6281752      4001
# 1      576334  6283873      4002
# 2      572027  6280312      4003
# 3      572027  6280312      4004
# 4      574294  6277699      4005
# ...       ...      ...       ...
# 55720  452460  6226722     43996
# 55721  574294  6277699     43997
# 55722  631428  6314715     43998
# 55723  574294  6277699     43999
# 55724  637820  6279364     44000
#
# [55725 rows x 20 columns]

# %%
occ['date'] = pd.to_datetime(occ['date_debut']).dt.to_period('M')
occ['date']
# Out:
# C:\Users\megan\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,
# 0        2020-01
# 1        2020-01
# 2        2020-01
# 3        2020-01
# 4        2020-01
#           ...
# 55720    2019-05
# 55721    2019-05
# 55722    2019-05
# 55723    2019-05
# 55724    2019-05
# Name: date, Length: 55725, dtype: period[M]

# %%
occ.nom_com.unique() # villes disponibles dans le data set
# Out:
# array(['TOULOUSE', 'SAINT-LAURENT-DES-ARBRES', 'LOURDES', 'CASTRES',
#        'SAINT-GELY-DU-FESC', 'SAINT-GAUDENS', 'BLAGNAC',
#        'PEYRUSSE-VIEILLE', 'MONTPELLIER', 'MIRAMONT-DE-COMMINGES',
#        'NIMES', 'LUNEL-VIEL', 'TARBES', 'AGDE', 'PERPIGNAN', 'ALBI',
#        'SAINT-ESTEVE', 'MENDE', 'LA CALMETTE', 'CAUNES-MINERVOIS',
#        'CORNEILHAN', 'RODEZ', 'BIARS-SUR-CERE', 'BESSIERES', 'LATTES',
#        'MONTGISCARD', 'BELESTA-EN-LAURAGAIS', 'SAZE', 'CARCASSONNE',
#        'VALLABREGUES', 'PAMIERS', 'ROQUEREDONDE'], dtype=object)

# %%
# choix des villes pour le wiget : Toulouse, Montpellier, Carcassonne
ville = 'MONTPELLIER', 'TOULOUSE', 'LOURDES'

# %%
occ.nom_dept.unique() # départements disponibles dans le data set
# tous ces départements constituent l'occitanie
# trouver une map adaptée !!
# Out:
# array(['HAUTE-GARONNE', 'GARD', 'HAUTES-PYRENEES', 'TARN', 'HERAULT',
#        'GERS', 'PYRENEES-ORIENTALES', 'LOZERE', 'AUDE', 'AVEYRON', 'LOT',
#        'ARIEGE'], dtype=object)

# %%
# On selectionne les données des 3 villes et du polluant qui nous interessent:

df_villes = occ[occ['nom_com'].isin(ville)]
df_villes = df_villes[df_villes['nom_poll'] == 'O3']

df_villes.tail(n=5)
# Out:
#               X        Y         nom_dept      nom_com  insee_com  \
# 55662  1.385410  43.5970    HAUTE-GARONNE     TOULOUSE      31555
# 55665  3.886890  43.5915          HERAULT  MONTPELLIER      34172
# 55673 -0.038889  43.0969  HAUTES-PYRENEES      LOURDES      65286
# 55719  1.418610  43.5756    HAUTE-GARONNE     TOULOUSE      31555
# 55720 -0.038889  43.0969  HAUTES-PYRENEES      LOURDES      65286
#
#                               nom_station code_station typologie influence  \
# 55662                 Station Pedagogique      FR50058   Urbaine      Fond
# 55665  Montpellier - Prés d Arènes Urbain      FR50200   Urbaine      Fond
# 55673               Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond
# 55719            Toulouse-Jacquier Urbain      FR50004   Urbaine      Fond
# 55720               Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond
#
#       nom_poll  ...  valeur   unite     metrique                date_debut  \
# 55662       O3  ...    60.4  ug.m-3  journaliere  2019-09-07T01:00:00.000Z
# 55665       O3  ...    76.5  ug.m-3  journaliere  2019-09-07T01:00:00.000Z
# 55673       O3  ...    57.6  ug.m-3  journaliere  2019-09-07T01:00:00.000Z
# 55719       O3  ...    65.7  ug.m-3  journaliere  2019-05-05T01:00:00.000Z
# 55720       O3  ...    67.3  ug.m-3  journaliere  2019-05-05T01:00:00.000Z
#
#                        date_fin statut_valid   x_l93    y_l93  ObjectId  \
# 55662  2019-09-08T00:00:00.000Z            t  569593  6278883     43938
# 55665  2019-09-08T00:00:00.000Z            t  771642  6277340     43941
# 55673  2019-09-08T00:00:00.000Z            t  452460  6226722     43949
# 55719  2019-05-06T00:00:00.000Z            t  572227  6276450     43995
# 55720  2019-05-06T00:00:00.000Z            t  452460  6226722     43996
#
#           date
# 55662  2019-09
# 55665  2019-09
# 55673  2019-09
# 55719  2019-05
# 55720  2019-05
#
# [5 rows x 21 columns]

# %%
df_villes.date.unique()
# On a les données journalières de mars 2019 à mars 2020 (WOW!)
# Out:
# <PeriodArray>
# ['2020-01', '2020-02', '2020-03', '2019-05', '2019-08', '2019-04', '2019-10',
#  '2019-09', '2019-03', '2019-07', '2019-06', '2019-11', '2019-12']
# Length: 13, dtype: period[M]

# %%
# On doit vérifier que chaque ville ait le même nombre de données:

# *********************** MISSION *******************************
# Choisir dans un premier temps un mois sur lequel se fixer pour le widget 
# Dans un second temps faire évoluer le widget en fonction des jours/mois

mtp = df_villes[df_villes['nom_com'] == 'MONTPELLIER'] # data frame de Montpellier et O3

# %%
mtp = mtp[mtp.date == '2020-01'] # On se fixe un mois, par exemple janvier 2020

# %%
mtp.code_station.unique()
# Out:
# array(['FR50200'], dtype=object)

# %%
print('Il y a', mtp.count()[0], 'données pour Montpellier au mois de janvier 2020')
# Out:
# Il y a 31 données pour Montpellier au mois de janvier 2020

# %%
tls = df_villes[df_villes['nom_com'] == 'TOULOUSE']

# %%
tls = tls[tls.date == '2020-01']

# %%
tls.code_station.unique() # On remarque qu'il y a 4 stations !! 
# pas bon pour avoir le même nombre de données que Mtp par exemple
# Out:
# array(['FR50058', 'FR50004', 'FR50021', 'FR50030'], dtype=object)

# %%
tls.count()[0] # effectivement il y en 118, beaucoup trop donc il faut choisir une station en particulier
# Out:
# 118

# %%
# On choisit par exemple la station qui s'appelle Toulouse Berthelot urbain et dont le code est FR50030
tls = tls[tls.code_station == 'FR50030']

# %%
tls.count()[0] # maintenant si on recompte il y en a bien 31
# Out:
# 31

# %%
lds = df_villes[df_villes['nom_com'] == 'LOURDES']
# Out:
#               X        Y         nom_dept  nom_com  insee_com  \
# 57    -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 174   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 369   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 577   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 739   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# ...         ...      ...              ...      ...        ...
# 55162 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 55200 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 55342 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 55673 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 55720 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
#
#                  nom_station code_station typologie influence nom_poll  ...  \
# 57     Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 174    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 369    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 577    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 739    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# ...                      ...          ...       ...       ...      ...  ...
# 55162  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 55200  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 55342  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 55673  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 55720  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
#
#        valeur   unite     metrique                date_debut  \
# 57       14.3  ug.m-3  journaliere  2020-01-15T01:00:00.000Z
# 174      28.6  ug.m-3  journaliere  2020-01-16T01:00:00.000Z
# 369      53.1  ug.m-3  journaliere  2020-01-17T01:00:00.000Z
# 577      49.2  ug.m-3  journaliere  2020-01-18T01:00:00.000Z
# 739      49.6  ug.m-3  journaliere  2020-01-19T01:00:00.000Z
# ...       ...     ...          ...                       ...
# 55162    80.1  ug.m-3  journaliere  2019-05-04T01:00:00.000Z
# 55200    54.3  ug.m-3  journaliere  2019-06-30T01:00:00.000Z
# 55342    29.1  ug.m-3  journaliere  2019-11-13T01:00:00.000Z
# 55673    57.6  ug.m-3  journaliere  2019-09-07T01:00:00.000Z
# 55720    67.3  ug.m-3  journaliere  2019-05-05T01:00:00.000Z
#
#                        date_fin statut_valid   x_l93    y_l93  ObjectId  \
# 57     2020-01-16T00:00:00.000Z            t  452460  6226722      4058
# 174    2020-01-17T00:00:00.000Z            t  452460  6226722      4175
# 369    2020-01-18T00:00:00.000Z            t  452460  6226722      4370
# 577    2020-01-19T00:00:00.000Z            t  452460  6226722      4578
# 739    2020-01-20T00:00:00.000Z            t  452460  6226722      4740
# ...                         ...          ...     ...      ...       ...
# 55162  2019-05-05T00:00:00.000Z            t  452460  6226722     43438
# 55200  2019-07-01T00:00:00.000Z            t  452460  6226722     43476
# 55342  2019-11-14T00:00:00.000Z            t  452460  6226722     43618
# 55673  2019-09-08T00:00:00.000Z            t  452460  6226722     43949
# 55720  2019-05-06T00:00:00.000Z            t  452460  6226722     43996
#
#           date
# 57     2020-01
# 174    2020-01
# 369    2020-01
# 577    2020-01
# 739    2020-01
# ...        ...
# 55162  2019-05
# 55200  2019-06
# 55342  2019-11
# 55673  2019-09
# 55720  2019-05
#
# [360 rows x 21 columns]

# %%
lds = lds[lds.date == '2020-01']
# Out:
#               X        Y         nom_dept  nom_com  insee_com  \
# 57    -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 174   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 369   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 577   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 739   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 900   -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 1211  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 1486  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 1688  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 1911  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 3016  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 3278  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 3501  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 3678  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 3828  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 4270  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 5129  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 5395  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 5696  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 5836  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 6061  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 6346  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 6588  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 6787  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 6988  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 9637  -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 13839 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 14710 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 20397 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 26031 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
# 28487 -0.038889  43.0969  HAUTES-PYRENEES  LOURDES      65286
#
#                  nom_station code_station typologie influence nom_poll  ...  \
# 57     Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 174    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 369    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 577    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 739    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 900    Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 1211   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 1486   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 1688   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 1911   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 3016   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 3278   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 3501   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 3678   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 3828   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 4270   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 5129   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 5395   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 5696   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 5836   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 6061   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 6346   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 6588   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 6787   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 6988   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 9637   Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 13839  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 14710  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 20397  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 26031  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
# 28487  Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond       O3  ...
#
#        valeur   unite     metrique                date_debut  \
# 57       14.3  ug.m-3  journaliere  2020-01-15T01:00:00.000Z
# 174      28.6  ug.m-3  journaliere  2020-01-16T01:00:00.000Z
# 369      53.1  ug.m-3  journaliere  2020-01-17T01:00:00.000Z
# 577      49.2  ug.m-3  journaliere  2020-01-18T01:00:00.000Z
# 739      49.6  ug.m-3  journaliere  2020-01-19T01:00:00.000Z
# 900      34.4  ug.m-3  journaliere  2020-01-20T01:00:00.000Z
# 1211     19.5  ug.m-3  journaliere  2020-01-07T01:00:00.000Z
# 1486     14.2  ug.m-3  journaliere  2020-01-08T01:00:00.000Z
# 1688     28.1  ug.m-3  journaliere  2020-01-09T01:00:00.000Z
# 1911     61.0  ug.m-3  journaliere  2020-01-10T01:00:00.000Z
# 3016     27.1  ug.m-3  journaliere  2020-01-21T01:00:00.000Z
# 3278     30.0  ug.m-3  journaliere  2020-01-22T01:00:00.000Z
# 3501     23.7  ug.m-3  journaliere  2020-01-23T01:00:00.000Z
# 3678     17.9  ug.m-3  journaliere  2020-01-24T01:00:00.000Z
# 3828     23.6  ug.m-3  journaliere  2020-01-25T01:00:00.000Z
# 4270     34.6  ug.m-3  journaliere  2020-01-26T01:00:00.000Z
# 5129     25.8  ug.m-3  journaliere  2020-01-11T01:00:00.000Z
# 5395     22.1  ug.m-3  journaliere  2020-01-12T01:00:00.000Z
# 5696     10.4  ug.m-3  journaliere  2020-01-13T01:00:00.000Z
# 5836     12.1  ug.m-3  journaliere  2020-01-14T01:00:00.000Z
# 6061     10.3  ug.m-3  journaliere  2020-01-02T01:00:00.000Z
# 6346     18.0  ug.m-3  journaliere  2020-01-03T01:00:00.000Z
# 6588     31.1  ug.m-3  journaliere  2020-01-04T01:00:00.000Z
# 6787     24.8  ug.m-3  journaliere  2020-01-05T01:00:00.000Z
# 6988     16.3  ug.m-3  journaliere  2020-01-06T01:00:00.000Z
# 9637     59.9  ug.m-3  journaliere  2020-01-28T01:00:00.000Z
# 13839    31.6  ug.m-3  journaliere  2020-01-01T01:00:00.000Z
# 14710    21.5  ug.m-3  journaliere  2020-01-29T01:00:00.000Z
# 20397    20.8  ug.m-3  journaliere  2020-01-27T01:00:00.000Z
# 26031    19.8  ug.m-3  journaliere  2020-01-30T01:00:00.000Z
# 28487    21.5  ug.m-3  journaliere  2020-01-31T01:00:00.000Z
#
#                        date_fin statut_valid   x_l93    y_l93  ObjectId  \
# 57     2020-01-16T00:00:00.000Z            t  452460  6226722      4058
# 174    2020-01-17T00:00:00.000Z            t  452460  6226722      4175
# 369    2020-01-18T00:00:00.000Z            t  452460  6226722      4370
# 577    2020-01-19T00:00:00.000Z            t  452460  6226722      4578
# 739    2020-01-20T00:00:00.000Z            t  452460  6226722      4740
# 900    2020-01-21T00:00:00.000Z            t  452460  6226722      4901
# 1211   2020-01-08T00:00:00.000Z            t  452460  6226722      2212
# 1486   2020-01-09T00:00:00.000Z            t  452460  6226722      2487
# 1688   2020-01-10T00:00:00.000Z            t  452460  6226722      2689
# 1911   2020-01-11T00:00:00.000Z            t  452460  6226722      2912
# 3016   2020-01-22T00:00:00.000Z            t  452460  6226722      5017
# 3278   2020-01-23T00:00:00.000Z            t  452460  6226722      5279
# 3501   2020-01-24T00:00:00.000Z            t  452460  6226722      5502
# 3678   2020-01-25T00:00:00.000Z            t  452460  6226722      5679
# 3828   2020-01-26T00:00:00.000Z            t  452460  6226722      5829
# 4270   2020-01-27T00:00:00.000Z            t  452460  6226722      6271
# 5129   2020-01-12T00:00:00.000Z            t  452460  6226722      3130
# 5395   2020-01-13T00:00:00.000Z            t  452460  6226722      3396
# 5696   2020-01-14T00:00:00.000Z            t  452460  6226722      3697
# 5836   2020-01-15T00:00:00.000Z            t  452460  6226722      3837
# 6061   2020-01-03T00:00:00.000Z            t  452460  6226722      1062
# 6346   2020-01-04T00:00:00.000Z            t  452460  6226722      1347
# 6588   2020-01-05T00:00:00.000Z            t  452460  6226722      1589
# 6787   2020-01-06T00:00:00.000Z            t  452460  6226722      1788
# 6988   2020-01-07T00:00:00.000Z            t  452460  6226722      1989
# 9637   2020-01-29T00:00:00.000Z            t  452460  6226722     12638
# 13839  2020-01-02T00:00:00.000Z            t  452460  6226722       840
# 14710  2020-01-30T00:00:00.000Z            t  452460  6226722     13711
# 20397  2020-01-28T00:00:00.000Z            t  452460  6226722      9398
# 26031  2020-01-31T00:00:00.000Z            t  452460  6226722     14032
# 28487  2020-02-01T00:00:00.000Z            t  452460  6226722     17488
#
#           date
# 57     2020-01
# 174    2020-01
# 369    2020-01
# 577    2020-01
# 739    2020-01
# 900    2020-01
# 1211   2020-01
# 1486   2020-01
# 1688   2020-01
# 1911   2020-01
# 3016   2020-01
# 3278   2020-01
# 3501   2020-01
# 3678   2020-01
# 3828   2020-01
# 4270   2020-01
# 5129   2020-01
# 5395   2020-01
# 5696   2020-01
# 5836   2020-01
# 6061   2020-01
# 6346   2020-01
# 6588   2020-01
# 6787   2020-01
# 6988   2020-01
# 9637   2020-01
# 13839  2020-01
# 14710  2020-01
# 20397  2020-01
# 26031  2020-01
# 28487  2020-01
#
# [31 rows x 21 columns]

# %%
lds.code_station.unique()
# Out:
# array(['FR50042'], dtype=object)

# %%
lds.count()[0] # assez de données, enfin car avant j'ai essayé carcassonne et perpignan qui avaient pas assez de data
# Out:
# 31

# %%
df_villes = df_villes[df_villes.date=='2020-01']

# %%
df = df[['nom_com', 'valeur']]
