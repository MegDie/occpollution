# %% [markdown]
# ### Ceci est un titre: Occitanie polution

# %%
# nous allons travailler en collaboration sur ce fichier
# svp essayer de rédiger directement en pep8
# Translate in english !!!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact  # widget manipulation

pd.options.display.max_rows = 10

# %% [markdown]
# # A terme, notre projet devra fournir:
#   + Une vidéo du niveau d'ozone en fonction du temps dans les villes d'occitanie, via certainement une map qui évolue en fonction du temps (contrainte: un cercle plus ou moins gros devra indiquer le niveau d'ozone) *DIFFICULTE +++*
#   + Un "widget" qui compare les niveaux de pollution de 3 villes grâce à des boxplot/violons *DIFFICULTE +*
#   + *DIFFICULTE ++* : faire varier le widget en fonction du temps
#   + Une comparaison Paris VS Montpellier *DIFFICULTE ?*

# %% [markdown]
# ## Importation et traitement des données mensuelles:

# %%
from download import download

# We choose daily data
url = "https://opendata.arcgis.com/datasets/2ab16a5fb61f42c1a689fd9cc466383f_0.csv"
path_target = "datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv"
download(url, path_target, replace=True)
# Out:
# Downloading data from https://opendata.arcgis.com/datasets/2ab16a5fb61f42c1a689fd9cc466383f_0.csv (1 byte)
# file_sizes: 10.9MB [00:09, 1.12MB/s]
# Successfully downloaded file to datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv
# 'datasets/Mesure_journaliere_Region_Occitanie_Polluants_Principaux.csv'

# %%
occ = pd.read_csv(path_target)
# all data of Occitanie

occ.head(n=5) # simpliest way too watch data
# Out:
#          X        Y             nom_dept      nom_com  insee_com  \
# 0  1.44389  43.5872        HAUTE-GARONNE     TOULOUSE      31555
# 1  1.43861  43.6236        HAUTE-GARONNE     TOULOUSE      31555
# 2  3.86472  43.6117              HERAULT  MONTPELLIER      34172
# 3  4.37422  43.8344                 GARD        NIMES      30189
# 4  2.89970  42.6958  PYRENEES-ORIENTALES    PERPIGNAN      66136
#
#                     nom_station code_station typologie influence nom_poll  \
# 0     Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond    PM2.5
# 1       Toulouse-Mazades Urbain      FR50021   Urbaine      Fond    PM2.5
# 2  Montpellier - Chaptal Urbain      FR50201   Urbaine      Fond       NO
# 3            Nîmes Sud - urbain      FR50211   Urbaine      Fond       NO
# 4     Perpignan Centre - urbain      FR50220   Urbaine      Fond       NO
#
#    id_poll_ue  valeur   unite     metrique                date_debut  \
# 0        6001     4.9  ug.m-3  journaliere  2020-03-05T01:00:00.000Z
# 1        6001     5.2  ug.m-3  journaliere  2020-03-05T01:00:00.000Z
# 2          38     6.9  ug.m-3  journaliere  2020-03-05T01:00:00.000Z
# 3          38     3.8  ug.m-3  journaliere  2020-03-05T01:00:00.000Z
# 4          38    11.8  ug.m-3  journaliere  2020-03-05T01:00:00.000Z
#
#                    date_fin statut_valid   x_l93    y_l93  ObjectId
# 0  2020-03-06T00:00:00.000Z            t  574294  6277699      7001
# 1  2020-03-06T00:00:00.000Z            t  573948  6281752      7002
# 2  2020-03-06T00:00:00.000Z            t  769827  6279565      7003
# 3  2020-03-06T00:00:00.000Z            t  810536  6304894      7004
# 4  2020-03-06T00:00:00.000Z            t  691771  6177360      7005

# %%
occ['date'] = pd.to_datetime(occ['date_debut']).dt.to_period('M')

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.to_period.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
# Out:
# C:\Users\megan\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %% [markdown]
# Description des variables:
#
#    + X et Y : coordonnées ?
#    + nom_dept : nom du département
#    + nom_com : nom de la commune
#    + insee_com: ?
#    + nom_station : station qui récolte les données
#    + code_station : code de la station
#    + typologie : type de zone
#    + influence : ce qui peut influencer la pollution
#    + nom_poll : nom du polluant
#    + id_poll_ue : identifiant du polluant
#    + valeur : valeur mesurée du polluant
#    + unite : unité
#    + date_debut: année/mois/jour/heure
#    + date_fin: idem
#    + status_valid : ?
#    + x_l93 : ?
#    + y_l93 : ?
#    + objectld : ?

# %%
# variables description
occ.describe()
# Out:
#                   X             Y     insee_com    id_poll_ue        valeur  \
# count  55645.000000  55645.000000  55645.000000  55645.000000  55645.000000
# mean       2.216018     43.559525  40386.623758    530.624656     25.246484
# std        1.408032      0.437011  17264.977529   1683.144151     30.558936
# min       -0.051944     42.684000   9225.000000      1.000000    -25.200000
# 25%        1.376000     43.230300  31483.000000      7.000000      6.300000
# 50%        1.845730     43.610000  32317.000000      8.000000     13.800000
# 75%        3.504830     43.675800  48095.000000     38.000000     32.900000
# max        4.697360     44.925400  81065.000000   6001.000000    815.600000
#
#                x_l93         y_l93      ObjectId
# count   55645.000000  5.564500e+04  55645.000000
# mean   636343.696630  6.274710e+06  27823.000000
# std    113981.279068  4.820360e+04  16063.472201
# min    451389.000000  6.176047e+06      1.000000
# 25%    568918.000000  6.241231e+06  13912.000000
# 50%    608927.000000  6.279364e+06  27823.000000
# 75%    740996.000000  6.286912e+06  41734.000000
# max    836000.000000  6.425805e+06  55645.000000

# %%
occ.nom_com.unique() # cities available in data set
# Out:
# array(['TOULOUSE', 'MONTPELLIER', 'NIMES', 'PERPIGNAN', 'SAINT-GAUDENS',
#        'TARBES', 'LOURDES', 'ALBI', 'CARCASSONNE', 'PEYRUSSE-VIEILLE',
#        'LUNEL-VIEL', 'CORNEILHAN', 'MONTGISCARD', 'SAINT-ESTEVE', 'AGDE',
#        'CASTRES', 'BLAGNAC', 'SAINT-LAURENT-DES-ARBRES',
#        'MIRAMONT-DE-COMMINGES', 'BESSIERES', 'RODEZ', 'CAUNES-MINERVOIS',
#        'BELESTA-EN-LAURAGAIS', 'MENDE', 'SAINT-GELY-DU-FESC', 'SAZE',
#        'LATTES', 'LA CALMETTE', 'VALLABREGUES', 'BIARS-SUR-CERE',
#        'PAMIERS', 'ROQUEREDONDE'], dtype=object)

# %%
# Cities choice : Toulouse, Montpellier, Carcassonne
ville = 'MONTPELLIER', 'TOULOUSE', 'LOURDES'

# %%
occ.nom_dept.unique() # county available in data set
# FIND A MAP!!!
# Out:
# array(['HAUTE-GARONNE', 'HERAULT', 'GARD', 'PYRENEES-ORIENTALES',
#        'HAUTES-PYRENEES', 'TARN', 'AUDE', 'GERS', 'AVEYRON', 'LOZERE',
#        'LOT', 'ARIEGE'], dtype=object)

# %%
# We select cities and ozone in df

df_villes = occ[occ['nom_com'].isin(ville)] # cities we want
df_villes = df_villes[df_villes['nom_poll'] == 'O3'] # only ozone
df_villes.tail(n=10) # end of df
# Out:
#               X        Y         nom_dept      nom_com  insee_com  \
# 55478  1.418610  43.5756    HAUTE-GARONNE     TOULOUSE      31555
# 55511  3.886890  43.5915          HERAULT  MONTPELLIER      34172
# 55516  1.443890  43.5872    HAUTE-GARONNE     TOULOUSE      31555
# 55517  1.438610  43.6236    HAUTE-GARONNE     TOULOUSE      31555
# 55518  1.385410  43.5970    HAUTE-GARONNE     TOULOUSE      31555
# 55526 -0.038889  43.0969  HAUTES-PYRENEES      LOURDES      65286
# 55632  1.443890  43.5872    HAUTE-GARONNE     TOULOUSE      31555
# 55633  1.438610  43.6236    HAUTE-GARONNE     TOULOUSE      31555
# 55636  1.385410  43.5970    HAUTE-GARONNE     TOULOUSE      31555
# 55639  3.886890  43.5915          HERAULT  MONTPELLIER      34172
#
#                               nom_station code_station typologie influence  \
# 55478            Toulouse-Jacquier Urbain      FR50004   Urbaine      Fond
# 55511  Montpellier - Prés d Arènes Urbain      FR50200   Urbaine      Fond
# 55516           Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond
# 55517             Toulouse-Mazades Urbain      FR50021   Urbaine      Fond
# 55518                 Station Pedagogique      FR50058   Urbaine      Fond
# 55526               Lourdes-Lapaca Urbain      FR50042   Urbaine      Fond
# 55632           Toulouse-Berthelot Urbain      FR50030   Urbaine      Fond
# 55633             Toulouse-Mazades Urbain      FR50021   Urbaine      Fond
# 55636                 Station Pedagogique      FR50058   Urbaine      Fond
# 55639  Montpellier - Prés d Arènes Urbain      FR50200   Urbaine      Fond
#
#       nom_poll  ...  valeur   unite     metrique                date_debut  \
# 55478       O3  ...    61.5  ug.m-3  journaliere  2020-02-11T01:00:00.000Z
# 55511       O3  ...    69.9  ug.m-3  journaliere  2020-02-11T01:00:00.000Z
# 55516       O3  ...    59.9  ug.m-3  journaliere  2020-02-11T01:00:00.000Z
# 55517       O3  ...    56.8  ug.m-3  journaliere  2020-02-11T01:00:00.000Z
# 55518       O3  ...    61.0  ug.m-3  journaliere  2020-02-11T01:00:00.000Z
# 55526       O3  ...    26.0  ug.m-3  journaliere  2020-03-18T01:00:00.000Z
# 55632       O3  ...    46.6  ug.m-3  journaliere  2020-02-12T01:00:00.000Z
# 55633       O3  ...    49.6  ug.m-3  journaliere  2020-02-12T01:00:00.000Z
# 55636       O3  ...    46.1  ug.m-3  journaliere  2020-02-12T01:00:00.000Z
# 55639       O3  ...    50.7  ug.m-3  journaliere  2020-02-12T01:00:00.000Z
#
#                        date_fin statut_valid   x_l93    y_l93  ObjectId  \
# 55478  2020-02-12T00:00:00.000Z            t  572227  6276450     51834
# 55511  2020-02-12T00:00:00.000Z            t  771642  6277340     51867
# 55516  2020-02-12T00:00:00.000Z            t  574294  6277699     51872
# 55517  2020-02-12T00:00:00.000Z            t  573948  6281752     51873
# 55518  2020-02-12T00:00:00.000Z            t  569593  6278883     51874
# 55526  2020-03-19T00:00:00.000Z            t  452460  6226722     51882
# 55632  2020-02-13T00:00:00.000Z            t  574294  6277699     51988
# 55633  2020-02-13T00:00:00.000Z            t  573948  6281752     51989
# 55636  2020-02-13T00:00:00.000Z            t  569593  6278883     51992
# 55639  2020-02-13T00:00:00.000Z            t  771642  6277340     51995
#
#           date
# 55478  2020-02
# 55511  2020-02
# 55516  2020-02
# 55517  2020-02
# 55518  2020-02
# 55526  2020-03
# 55632  2020-02
# 55633  2020-02
# 55636  2020-02
# 55639  2020-02
#
# [10 rows x 21 columns]

# %%
df_villes.date.unique()
# We have daily data from march 2019 to march 2020 (WOW!)
# Out:
# <PeriodArray>
# ['2020-03', '2019-05', '2019-08', '2019-04', '2019-10', '2019-09', '2020-01',
#  '2020-02', '2019-12', '2019-11', '2019-07', '2019-03', '2019-06']
# Length: 13, dtype: period[M]

# %% [markdown]
# On va maintenant implémenter le widget qui compare la polution dans 3 villes en fonction du temps:

# %%
# We have to count how many data each city has for each month

mtp = df_villes[df_villes['nom_com'] == 'MONTPELLIER'] # data frame of Montpellier and O3
print(mtp.code_station.unique()) # how many station in Montpellier?
mtp = mtp[mtp.date == '2019-12'] # We choose one month (for exemple)

print('There are', mtp.count()[0], 'data for', mtp.nom_com.unique(), 'in', mtp.date.unique() ) 

tls = df_villes[df_villes['nom_com'] == 'TOULOUSE']
tls = tls[tls.date == '2019-12']
tls = tls[tls.code_station == 'FR50030']
print(tls.code_station.unique())

print('There are', tls.count()[0], 'data for', tls.nom_com.unique(), 'in', tls.date.unique())

lds = df_villes[df_villes['nom_com'] == 'LOURDES']
print(lds.code_station.unique())
lds = lds[lds.date == '2019-12']

print('Il y a', lds.count()[0], 'data for', lds.nom_com.unique(), 'in', lds.date.unique()) 

# not the same number of data in 2019-07, 2019-08, 09
# Out:
# ['FR50200']
# There are 31 data for ['MONTPELLIER'] in <PeriodArray>
# ['2019-12']
# Length: 1, dtype: period[M]
# ['FR50030']
# There are 31 data for ['TOULOUSE'] in <PeriodArray>
# ['2019-12']
# Length: 1, dtype: period[M]
# ['FR50042']
# Il y a 31 data for ['LOURDES'] in <PeriodArray>
# ['2019-12']
# Length: 1, dtype: period[M]

# %%
station = 'FR50030', 'FR50200', 'FR50042'
df_villes = df_villes[df_villes['code_station'].isin(station)]
df_villes = df_villes[['nom_com', 'code_station', 'valeur', 'date']]
df_villes.head(n=8)
# Out:
#          nom_com code_station  valeur     date
# 129     TOULOUSE      FR50030    72.1  2020-03
# 133      LOURDES      FR50042    80.6  2020-03
# 160  MONTPELLIER      FR50200    72.2  2020-03
# 263     TOULOUSE      FR50030    63.3  2020-03
# 274  MONTPELLIER      FR50200    78.4  2020-03
# 277      LOURDES      FR50042    66.2  2020-03
# 409     TOULOUSE      FR50030    56.4  2020-03
# 421      LOURDES      FR50042    55.5  2020-03

# %%
df_villes.date.unique()
# Out:
# <PeriodArray>
# ['2020-03', '2019-05', '2019-08', '2019-04', '2019-10', '2019-09', '2020-01',
#  '2020-02', '2019-12', '2019-11', '2019-07', '2019-03', '2019-06']
# Length: 13, dtype: period[M]

# %%
sns.catplot(x = 'nom_com', y = 'valeur', 
            data = df_villes,
            height = 3, aspect = 2,
            kind = 'violin')

# ceci n'est qu'un boxplot avec plein d'erreurs, il faut un widget, que doit on faire varier?
# il faudrait garder les mois pour faire un widget en fonction des mois
# il faut s'assurer que pour tous les mois, il y ait le bon nombre de données...

# %%
def poluted_cities(mois):
    df_villes_plot = df_villes[df_villes.date == mois]
    sns.catplot(x = 'nom_com', y = 'valeur', 
            data = df_villes_plot,
            height = 3, aspect = 2,
            kind = 'violin')
    plt.tight_layout()
    plt.show()
    
# on pourrait également choisir les villes dans le widget !!!!!!!!! prochaine mission !
# modifier le nom des axes
# mettre un titre

# %%
interact(poluted_cities, mois=df_villes.date.unique())
# Out:
# interactive(children=(Dropdown(description='mois', options=(Period('2020-03', 'M'), Period('2019-05', 'M'), Pe…
# <function __main__.poluted_cities(mois)>
