# %%
import pandas as pd

# %%
path_target = 'Paris_2018.csv'
polution_df = pd.read_csv('Paris_2018.csv', sep=';',
                          comment='#',
                          na_values="n/d",
                          converters={'heure': str})

polution_df
# Out:
#             date heure      MELUN     VILLEM     LOGNES      CERGY       PA13  \
# 0            NaN        microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1     01/01/2018     1         72         79         76         81         73
# 2     01/01/2018     2         72         80         78         81         73
# 3     01/01/2018     3         69         77         77         77         70
# 4     01/01/2018     4         68         73         74         75         67
# ...          ...   ...        ...        ...        ...        ...        ...
# 8756  31/12/2018    20          2         12          1         31         30
# 8757  31/12/2018    21          2         24          1         31         34
# 8758  31/12/2018    22          2         35          1         36         33
# 8759  31/12/2018    23          2         28         19         34         43
# 8760  31/12/2018    24          4         41         30         44         46
#
# ...
